# %%
from matplotlib import dates
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf

# %%
data = yf.download('SPY AAPL',start='2010-01-01',end='2023-06-27')
data
# Out:
# [*********************100%***********************]  2 of 2 completed
#              Adj Close                   Close                    High  \
#                   AAPL         SPY        AAPL         SPY        AAPL
# Date
# 2010-01-04    6.496294   87.791779    7.643214  113.330002    7.660714
# 2010-01-05    6.507525   88.024178    7.656429  113.629997    7.699643
# 2010-01-06    6.404015   88.086128    7.534643  113.709999    7.686786
# 2010-01-07    6.392176   88.458000    7.520714  114.190002    7.571429
# 2010-01-08    6.434673   88.752373    7.570714  114.570000    7.571429
# ...                ...         ...         ...         ...         ...
# 2023-06-20  185.009995  437.179993  185.009995  437.179993  186.100006
# 2023-06-21  183.960007  434.940002  183.960007  434.940002  185.410004
# 2023-06-22  187.000000  436.510010  187.000000  436.510010  187.050003
# 2023-06-23  186.679993  433.209991  186.679993  433.209991  187.559998
# 2023-06-26  185.270004  431.440002  185.270004  431.440002  188.050003
#
#                                Low                    Open              \
#                    SPY        AAPL         SPY        AAPL         SPY
# Date
# 2010-01-04  113.389999    7.585000  111.510002    7.622500  112.370003
# 2010-01-05  113.680000    7.616071  112.849998    7.664286  113.260002
# 2010-01-06  113.989998    7.526786  113.430000    7.656429  113.519997
# 2010-01-07  114.330002    7.466071  113.180000    7.562500  113.500000
# 2010-01-08  114.620003    7.466429  113.660004    7.510714  113.889999
# ...                ...         ...         ...         ...         ...
# 2023-06-20  438.369995  184.410004  435.029999  184.410004  437.450012
# 2023-06-21  436.989990  182.589996  434.329987  184.899994  436.160004
# 2023-06-22  436.619995  183.669998  433.600006  183.740005  433.950012
# 2023-06-23  435.059998  185.009995  432.470001  185.550003  432.929993
# 2023-06-26  434.609985  185.229996  431.190002  186.830002  432.619995
#
#                Volume
#                  AAPL        SPY
# Date
# 2010-01-04  493729600  118944600
# 2010-01-05  601904800  111579900
# 2010-01-06  552160000  116074400
# 2010-01-07  477131200  131091100
# 2010-01-08  447610800  126402800
# ...               ...        ...
# 2023-06-20   49799100   76160400
# 2023-06-21   49515700   76982300
# 2023-06-22   51245300   70637200
# 2023-06-23   53079300   92028700
# 2023-06-26   48088700   72823600
#
# [3392 rows x 12 columns]

# %%
data.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',  'SPY')],
#            )

# %%
# with a ? at the end will tell us about the 
data.pipe?

# %%
def fix_col(df):
    col = df.columns
    outer= [cols[0] for cols in col]
    df.columns = outer
    return df
(data
.iloc[:, ::2]
.pipe(fix_col)
)
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2010-01-04    6.496295    7.643214    7.660714    7.585000    7.622500
# 2010-01-05    6.507526    7.656429    7.699643    7.616071    7.664286
# 2010-01-06    6.404014    7.534643    7.686786    7.526786    7.656429
# 2010-01-07    6.392175    7.520714    7.571429    7.466071    7.562500
# 2010-01-08    6.434674    7.570714    7.571429    7.466429    7.510714
# ...                ...         ...         ...         ...         ...
# 2023-06-20  185.009995  185.009995  186.100006  184.410004  184.410004
# 2023-06-21  183.960007  183.960007  185.410004  182.589996  184.899994
# 2023-06-22  187.000000  187.000000  187.050003  183.669998  183.740005
# 2023-06-23  186.679993  186.679993  187.559998  185.009995  185.550003
# 2023-06-26  185.270004  185.270004  188.050003  185.229996  186.830002
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# 2010-01-07  477131200
# 2010-01-08  447610800
# ...               ...
# 2023-06-20   49799100
# 2023-06-21   49515700
# 2023-06-22   51245300
# 2023-06-23   53079300
# 2023-06-26   48088700
#
# [3392 rows x 6 columns]

# %%
### Load Data
# we can convert this into one  function for finance

import yfinance as yf
def fix_col(df):
    col = df.columns
    outer= [cols[0] for cols in col]
    df.columns = outer
    return df
def tweak():
    data = yf.download('SPY AAPL',start='2010-01-01',end='2023-06-27')
    return(data.iloc[:,::2].pipe(fix_col))
tweak()
# Out:
# [*********************100%***********************]  2 of 2 completed
#              Adj Close       Close        High         Low        Open  \
# Date
# 2010-01-04    6.496294    7.643214    7.660714    7.585000    7.622500
# 2010-01-05    6.507527    7.656429    7.699643    7.616071    7.664286
# 2010-01-06    6.404015    7.534643    7.686786    7.526786    7.656429
# 2010-01-07    6.392175    7.520714    7.571429    7.466071    7.562500
# 2010-01-08    6.434673    7.570714    7.571429    7.466429    7.510714
# ...                ...         ...         ...         ...         ...
# 2023-06-20  185.009995  185.009995  186.100006  184.410004  184.410004
# 2023-06-21  183.960007  183.960007  185.410004  182.589996  184.899994
# 2023-06-22  187.000000  187.000000  187.050003  183.669998  183.740005
# 2023-06-23  186.679993  186.679993  187.559998  185.009995  185.550003
# 2023-06-26  185.270004  185.270004  188.050003  185.229996  186.830002
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# 2010-01-07  477131200
# 2010-01-08  447610800
# ...               ...
# 2023-06-20   49799100
# 2023-06-21   49515700
# 2023-06-22   51245300
# 2023-06-23   53079300
# 2023-06-26   48088700
#
# [3392 rows x 6 columns]

# %%
### Line Plots

(data
 .iloc[:,:-2:2]
 .pipe(fix_col)
 .plot())
# Out:
# <Axes: xlabel='Date'>

# %%
(data
 .iloc[:,::2]
 .pipe(fix_col)
 .Close
 .plot())
# Out:
# <Axes: xlabel='Date'>

# %%
#Resampling : taking data from one granulatiy to other granuality like from daily to weekly monthly of quarterly
(data
.iloc[:,::2]
.pipe(fix_col)
.resample('M')
.Close
.mean()
.plot() 
)
# Out:
# <Axes: xlabel='Date'>

# %%
(data
.iloc[:,::2]
.pipe(fix_col)
.resample('Q')
.Close
.mean()
.plot() 
)
# Out:
# <Axes: xlabel='Date'>

# %%
#Candle stick plot
fig,ax = plt.subplots(figsize=(10,5))
def candlestick(df,ax):
    ax.vlines(x=df.index, ymin=df.Low, ymax=df.High, color='r', linewidth=1)
    red = df.query('Open > Close')
    ax.vlines(x=red.index,ymin=red.Close, ymax=red.Open, color='r', linewidth=3)
    green = df.query('Open <= Close')
    ax.vlines(x=green.index,ymin=green.Open, ymax=green.Close, color='g', linewidth=3)
    ax.xaxis.set_major_locator(dates.MonthLocator())
    ax.xaxis.set_major_formatter(dates.DateFormatter('%b-%y'))
    ax.xaxis.set_minor_locator(dates.DayLocator())
    return df
(data
.iloc[:,::2]
.pipe(fix_col)
.resample('d')
.agg({'Close':'last', 'Open':'first',  'High':'max', 'Low':'min'})
.loc['jan 2018':'March 2018']
.pipe(candlestick,ax) 
)
# Out:
#                 Close       Open       High        Low
# Date
# 2018-01-01        NaN        NaN        NaN        NaN
# 2018-01-02  43.064999  42.540001  43.075001  42.314999
# 2018-01-03  43.057499  43.132500  43.637501  42.990002
# 2018-01-04  43.257500  43.134998  43.367500  43.020000
# 2018-01-05  43.750000  43.360001  43.842499  43.262501
# ...               ...        ...        ...        ...
# 2018-03-27  42.084999  43.419998  43.787498  41.730000
# 2018-03-28  41.619999  41.812500  42.505001  41.297501
# 2018-03-29  41.945000  41.952499  42.937500  41.724998
# 2018-03-30        NaN        NaN        NaN        NaN
# 2018-03-31        NaN        NaN        NaN        NaN
#
# [90 rows x 4 columns]

# %% [markdown]
# ### Some question/Challenges

# %%
# CandlePlot for Sep2019 to Dec 2019
fig,ax = plt.subplots(figsize=(10,5))
def candlestick(df,ax):
    ax.vlines(x=df.index, ymin=df.Low, ymax=df.High, color='r', linewidth=1)
    red = df.query('Open > Close')
    ax.vlines(x=red.index,ymin=red.Close, ymax=red.Open, color='r', linewidth=3)
    green = df.query('Open <= Close')
    ax.vlines(x=green.index,ymin=green.Open, ymax=green.Close, color='g', linewidth=3)
    ax.xaxis.set_major_locator(dates.MonthLocator())
    ax.xaxis.set_major_formatter(dates.DateFormatter('%b-%y'))
    ax.xaxis.set_minor_locator(dates.DayLocator())
    return df
(data
 .iloc[:,::2]
 .pipe(fix_col)
 .resample('d')
 .agg({'Close':'last', 'Open':'first',  'High':'max', 'Low':'min'})
 .loc['Sep 2019':'Dec 2019']
 .pipe(candlestick,ax)
)
# Out:
#                 Close       Open       High        Low
# Date
# 2019-09-01        NaN        NaN        NaN        NaN
# 2019-09-02        NaN        NaN        NaN        NaN
# 2019-09-03  51.424999  51.607498  51.744999  51.055000
# 2019-09-04  52.297501  52.097500  52.369999  51.830002
# 2019-09-05  53.320000  53.000000  53.492500  52.877499
# ...               ...        ...        ...        ...
# 2019-12-27  72.449997  72.779999  73.492500  72.029999
# 2019-12-28        NaN        NaN        NaN        NaN
# 2019-12-29        NaN        NaN        NaN        NaN
# 2019-12-30  72.879997  72.364998  73.172501  71.305000
# 2019-12-31  73.412498  72.482498  73.419998  72.379997
#
# [122 rows x 4 columns]

# %%
#Returns

app = (data
       .iloc[:,::2]
       .pipe(fix_col)
      )

app
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2010-01-04    6.496294    7.643214    7.660714    7.585000    7.622500
# 2010-01-05    6.507525    7.656429    7.699643    7.616071    7.664286
# 2010-01-06    6.404015    7.534643    7.686786    7.526786    7.656429
# 2010-01-07    6.392176    7.520714    7.571429    7.466071    7.562500
# 2010-01-08    6.434673    7.570714    7.571429    7.466429    7.510714
# ...                ...         ...         ...         ...         ...
# 2023-06-20  185.009995  185.009995  186.100006  184.410004  184.410004
# 2023-06-21  183.960007  183.960007  185.410004  182.589996  184.899994
# 2023-06-22  187.000000  187.000000  187.050003  183.669998  183.740005
# 2023-06-23  186.679993  186.679993  187.559998  185.009995  185.550003
# 2023-06-26  185.270004  185.270004  188.050003  185.229996  186.830002
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# 2010-01-07  477131200
# 2010-01-08  447610800
# ...               ...
# 2023-06-20   49799100
# 2023-06-21   49515700
# 2023-06-22   51245300
# 2023-06-23   53079300
# 2023-06-26   48088700
#
# [3392 rows x 6 columns]

# %%
app.diff()
# Out:
#             Adj Close     Close      High       Low      Open       Volume
# Date
# 2010-01-04        NaN       NaN       NaN       NaN       NaN          NaN
# 2010-01-05   0.011231  0.013215  0.038929  0.031071  0.041786  108175200.0
# 2010-01-06  -0.103510 -0.121786 -0.012857 -0.089285 -0.007857  -49744800.0
# 2010-01-07  -0.011839 -0.013929 -0.115357 -0.060715 -0.093929  -75028800.0
# 2010-01-08   0.042497  0.050000  0.000000  0.000358 -0.051786  -29520400.0
# ...               ...       ...       ...       ...       ...          ...
# 2023-06-20   0.089996  0.089996 -0.889999  0.139999 -2.319992  -51436500.0
# 2023-06-21  -1.049988 -1.049988 -0.690002 -1.820007  0.489990    -283400.0
# 2023-06-22   3.039993  3.039993  1.639999  1.080002 -1.159988    1729600.0
# 2023-06-23  -0.320007 -0.320007  0.509995  1.339996  1.809998    1834000.0
# 2023-06-26  -1.409988 -1.409988  0.490005  0.220001  1.279999   -4990600.0
#
# [3392 rows x 6 columns]

# %%
# percentage change r2-r1/r2
app.pct_change()
# Out:
#             Adj Close     Close      High       Low      Open    Volume
# Date
# 2010-01-04        NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05   0.001729  0.001729  0.005082  0.004096  0.005482  0.219098
# 2010-01-06  -0.015906 -0.015906 -0.001670 -0.011723 -0.001025 -0.082646
# 2010-01-07  -0.001849 -0.001849 -0.015007 -0.008066 -0.012268 -0.135882
# 2010-01-08   0.006648  0.006648  0.000000  0.000048 -0.006848 -0.061871
# ...               ...       ...       ...       ...       ...       ...
# 2023-06-20   0.000487  0.000487 -0.004760  0.000760 -0.012424 -0.508087
# 2023-06-21  -0.005675 -0.005675 -0.003708 -0.009869  0.002657 -0.005691
# 2023-06-22   0.016525  0.016525  0.008845  0.005915 -0.006274  0.034930
# 2023-06-23  -0.001711 -0.001711  0.002727  0.007296  0.009851  0.035789
# 2023-06-26  -0.007553 -0.007553  0.002613  0.001189  0.006898 -0.094022
#
# [3392 rows x 6 columns]

# %%
# Plotting return
(app
 .pct_change()
 .Close
 .plot()
)
# Out:
# <Axes: xlabel='Date'>

# %%
(app
 .pct_change()
 .Close
 .hist()
)
# Out:
# <Axes: >

# %%
(app
 .pct_change()
 .Close
 .hist(bins=40)
)
# Out:
# <Axes: >

# %% [markdown]
# #

# %% [markdown]
# ### Bar plot
# Bar plots are commonly used in finance to visualize various aspects of financial data, such as comparing different assets, showing performance metrics, or displaying market trends.  Here we can plot the bar plot lets plot it for last 50 values and basically index is going to go into the X-axis and then each value will be a bar at that point.
#
# In pandas for bar plot it convert each value to categorial and thats why its show all zhe labels to fix it

# %%
(app
 .pct_change()
 .Close
 .iloc[-50:]
 .plot.bar()
)
# Out:
# <Axes: xlabel='Date'>

# %%
def my_bar(ser,ax):
    ax.bar(ser.index,ser)
    ax.xaxis.set_major_locator(dates.MonthLocator())
    ax.xaxis.set_major_formatter(dates.DateFormatter('%b-%y'))
    ax.xaxis.set_minor_locator(dates.DayLocator())
    return ser

fig,ax = plt.subplots(figsize=(10,5))
(app
 .pct_change()
 .Close
 .iloc[-100:]   #max ticks is 1000
 .pipe(my_bar,ax)
)
# Out:
# Date
# 2023-02-01    0.007901
# 2023-02-02    0.037063
# 2023-02-03    0.024400
# 2023-02-06   -0.017929
# 2023-02-07    0.019245
#                 ...
# 2023-06-20    0.000487
# 2023-06-21   -0.005675
# 2023-06-22    0.016525
# 2023-06-23   -0.001711
# 2023-06-26   -0.007553
# Name: Close, Length: 100, dtype: float64

# %%
#Cummulative return : Cumulative Return = (Final Value / Initial Value) - 1
# By Cumulative Return nvestors can assess the overall performance and growth of their investments over time,
#enabling them to make informed decisions about their portfolios.
(app
 .Close
 .sub(app.Close[0])
 .div(app.Close[0])
 .plot()
)
# Out:
# <Axes: xlabel='Date'>

# %%
#Inn fun

def com_return(df,col):
    ser= df[col]
    return(ser.sub(ser[0]).div(ser[0]))

(app
 .pipe(com_return,'Close')
 .plot()
)
# Out:
# <Axes: xlabel='Date'>

# %%
## if we need to add a new column can be dome qith a help of assign and lambda funda
app.assign(com_returns=lambda df:com_return(df,'Close'))
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2010-01-04    6.496294    7.643214    7.660714    7.585000    7.622500
# 2010-01-05    6.507525    7.656429    7.699643    7.616071    7.664286
# 2010-01-06    6.404015    7.534643    7.686786    7.526786    7.656429
# 2010-01-07    6.392176    7.520714    7.571429    7.466071    7.562500
# 2010-01-08    6.434673    7.570714    7.571429    7.466429    7.510714
# ...                ...         ...         ...         ...         ...
# 2023-06-20  185.009995  185.009995  186.100006  184.410004  184.410004
# 2023-06-21  183.960007  183.960007  185.410004  182.589996  184.899994
# 2023-06-22  187.000000  187.000000  187.050003  183.669998  183.740005
# 2023-06-23  186.679993  186.679993  187.559998  185.009995  185.550003
# 2023-06-26  185.270004  185.270004  188.050003  185.229996  186.830002
#
#                Volume  com_returns
# Date
# 2010-01-04  493729600     0.000000
# 2010-01-05  601904800     0.001729
# 2010-01-06  552160000    -0.014205
# 2010-01-07  477131200    -0.016027
# 2010-01-08  447610800    -0.009486
# ...               ...          ...
# 2023-06-20   49799100    23.205784
# 2023-06-21   49515700    23.068409
# 2023-06-22   51245300    23.466147
# 2023-06-23   53079300    23.424278
# 2023-06-26   48088700    23.239803
#
# [3392 rows x 7 columns]

# %%
## bar plot ffor cummulative return
def my_bar(ser,ax):
    ax.bar(ser.index,ser)
    ax.xaxis.set_major_locator(dates.MonthLocator())
    ax.xaxis.set_major_formatter(dates.DateFormatter('%b-%y'))
    ax.xaxis.set_minor_locator(dates.DayLocator())
    return ser

fig,ax = plt.subplots(figsize=(10,5))
(app
 #.resample('Q')
 #.mean()
 .pipe(com_return,'Close')
 .iloc[-40:]  #max ticks is 1000
 .pipe(my_bar,ax)
)
# Out:
# Date
# 2023-04-28    21.200083
# 2023-05-01    21.188309
# 2023-05-02    21.050931
# 2023-05-03    20.908322
# 2023-05-04    20.691135
# 2023-05-05    21.709033
# 2023-05-08    21.699874
# 2023-05-09    21.473530
# 2023-05-10    21.707724
# 2023-05-11    21.732583
# 2023-05-12    21.578198
# 2023-05-15    21.512781
# 2023-05-16    21.512781
# 2023-05-17    21.593898
# 2023-05-18    21.902669
# 2023-05-19    21.917061
# 2023-05-22    21.791458
# 2023-05-23    21.446054
# 2023-05-24    21.482687
# 2023-05-25    21.633149
# 2023-05-26    21.952385
# 2023-05-30    22.197047
# 2023-05-31    22.190505
# 2023-06-01    22.562076
# 2023-06-02    22.674594
# 2023-06-05    22.495351
# 2023-06-06    22.446943
# 2023-06-07    22.265082
# 2023-06-08    22.624878
# 2023-06-09    22.675904
# 2023-06-12    23.046165
# 2023-06-13    22.983365
# 2023-06-14    23.067099
# 2023-06-15    23.336619
# 2023-06-16    23.194010
# 2023-06-20    23.205784
# 2023-06-21    23.068409
# 2023-06-22    23.466147
# 2023-06-23    23.424278
# 2023-06-26    23.239803
# Name: Close, dtype: float64

# %% [markdown]
# ### Volality
#
# volatility refers to the degree of variation or fluctuation in the price or value of a financial instrument, such as stocks, bonds, or commodities, over a specific period. It is a measure of the uncertainty or risk associated with an investment.
#
# Volatility is commonly used to assess the potential price movements and riskiness of an asset. Higher volatility indicates larger price swings and greater uncertainty, while lower volatility suggests more stable and predictable price movements.
#
# There are different methods to measure volatility, but two commonly used measures are:
#
# Standard Deviation: The standard deviation is a statistical measure that quantifies the dispersion of a
# dataset from its mean. In finance, it is often used to calculate historical volatility.
# By analyzing the historical price data, the standard deviation provides an estimate of
# how much the prices have deviated from the average in the past. Higher standard deviation
# indicates higher volatility.
#
# Volatility Index (VIX): The VIX is a popular index that measures the implied volatility of the options market.
# It reflects the market's expectations of future volatility. The VIX is often referred to as the "fear index" as it tends to rise during times of market stress and uncertainty.
# Volatility plays a crucial role in various aspects of finance, such as risk management, option pricing, portfolio construction, and trading strategies. It helps investors and traders assess the potential risks and rewards associated with different investments and make informed decisions.
#
# It's important to note that volatility is not the same as the direction of price movements.
# A highly volatile asset can have significant price swings in both positive and negative directions,
# while a less volatile asset may have relatively smaller and more predictable price movements.
#
# By understanding and analyzing volatility, market participants can better evaluate the potential
# risks and returns of their investments and adapt their strategies accordingly.

# %%
(app
.Close
.mean())
# Out:
# 55.16324859716982

# %%
(app
.Close
.std())
# Out:
# 50.73869814580789

# %%
(app
.assign(pct_change_ = app.Close.pct_change())
.pct_change_
.std() 
)
# Out:
# 0.017961402006385203

# %% [markdown]
# ### Rolling
#
# Concept of "rolling" refers to a technique of calculating metrics or performing calculations repeatedly on a moving or rolling window of data. Rolling calculations are commonly used to analyze time-series data, such as stock prices, economic indicators, or financial ratios, in order to observe trends or patterns over a specified period.
#
# The rolling window typically consists of a fixed number of consecutive observations or a defined time period. As new data becomes available, the window moves forward in time, and the calculations are updated using the latest observations while dropping the oldest ones.
#
# With rolling  we can have rolling mean ( Moving averages), Rolling standard deviation (Volality), rolling sum, rolling corelations
#
#
# (app
# .assign(rolling=rolling(30).Close.)
#
# )
